# %%
from snake_game import *
import numpy as np
import gymnasium as gym
from dataclasses import dataclass

np.random.seed(0)

env = SnakeGame(render_mode="human")
env.render()

env2 = SnakeGame(render_mode="human")
env2.render()

# %%
import numpy as np
import matplotlib.pyplot as plt

eps = 0.9999
anneal_factor = 0.9999
n_steps = 100000

y = eps * anneal_factor ** np.arange(n_steps)
plt.plot(y)
plt.title("Epsilon")
plt.xlabel("steps")
plt.show()
